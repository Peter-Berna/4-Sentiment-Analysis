# %%
import pandas as pd
import sqlalchemy as alch
import os
import dotenv 

dotenv.load_dotenv()

password = os.getenv("sql_password")
dbName = "disney"
connectionData = f"mysql+pymysql://root:{password}@disney/{dbName}"
engine = alch.create_engine(connectionData)

df = pd.read_csv('src/DisneylandReviews.csv', sep=',', encoding='latin-1')
df.to_sql('tablename', con=engine)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/IronhackDAFT/lib/python3.9/site-packages/pymysql/connections.py:613, in Connection.connect(self, sock)
#     612 try:
# --> 613     sock = socket.create_connection(
#     614         (self.host, self.port), self.connect_timeout, **kwargs
#     615     )
#     616     break
#
# File ~/opt/anaconda3/envs/IronhackDAFT/lib/python3.9/socket.py:823, in create_connection(address, timeout, source_address)
#     822 err = None
# --> 823 for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     824     af, socktype, proto, canonname, sa = res
#
# File ~/opt/anaconda3/envs/IronhackDAFT/lib/python3.9/socket.py:954, in getaddrinfo(host, port, family, type, proto, flags)
#     953 addrlist = []
# --> 954 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
password
# Out:
# 'password'

# %%
import pandas as pd

# %%
df = pd.read_csv('src/DisneylandReviews.csv', sep=',', encoding='latin-1')

# %%
df.sample(5)
# Out:
#        Review_ID  Rating Year_Month Reviewer_Location  \
# 24956  151600022       5    2012-12     United States
# 38928  182926194       5    2013-10    United Kingdom
# 36163  281125321       2     2015-6            Canada
# 38650  191830020       5     2014-1    United Kingdom
# 4292   367243018       5     2016-4       Philippines
#
#                                              Review_Text  \
# 24956  Disneyland Park, Anaheim is a wow and breath t...
# 38928  Just come back from a 4 night   5 day trip. Th...
# 36163  Being a Disney fan, having visited Walt Disney...
# 38650  First family trip to disneyland and this park ...
# 4292   My daughter's smile says it all.  Disney is re...
#
#                       Branch  Year
# 24956  Disneyland_California  2012
# 38928       Disneyland_Paris  2013
# 36163       Disneyland_Paris  2015
# 38650       Disneyland_Paris  2014
# 4292     Disneyland_HongKong  2016

# %%
df['Year'] = df['Year_Month'].str.extract('(\d{4})', expand=True)

# %%
df['Year'].isna().sum()
# Out:
# 2613
